# %%
x = pi -sin(4) 
3x^2 + 2x -5
# Out:
# 48.3892445086433

# %%
x
# Out:
# 3.8983951488977215

# %%
using PyPlot
x = linspace(0, 2pi, 100)
y = sin(3x + 4cos (2x))
plot(x,y,color="red", linewidth=2.0, linestyle="--" )
title("Plot an oscillatory function")
xlabel("The X axis")
# Out:
# INFO: Precompiling module PyPlot...
# INFO: Installing matplotlib via the Conda package...
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3671FFD0>)
# PyObject <matplotlib.text.Text object at 0x368BCBD0>
